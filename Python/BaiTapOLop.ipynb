# %%
a = int(input("Nhập giá trị a: "))
b = int(input("Nhập giá trị b: "))
tong = a + b
hieu = a - b
tich = a * b
thuong = a / b

print(tong)
print(hieu)
print(tich)
print(thuong)
# Out:
# Nhập giá trị a: 3
# Nhập giá trị b: 2
# 5
# 1
# 6
# 1.5

# %%
#bài 2
chuoi = "Hello World"
laykytu = chuoi[2:5]

print (laykytu)
# Out:
# llo

# %%
#bài 3 xóa khoản trắng thuawaf cở đầu và chuổi ký tự
chuoi = "   Hello World  "
print(chuoi.strip().replace("H","J"))
# Out:
# Jello World

# %%
#bài 4 Nếu a lớn hơn b thì in ra hello world
a = int(input("Nhập a:"))
b = int(input("Nhập b:"))
if a>b:
  print(chuoi.strip())
else:
  print("không in ra")
# Out:
# Nhập a:2
# Nhập b:2
# không in ra

# %%
#bài 5: in ra Yes nếu a = b, ngược lại "No"
a=2
b=2
if a==b:
  print("Yes")
else:
  print("No")
# Out:
# Yes

# %%
#6.	In 1 nếu a bằng b, in 2 nếu a > b, in 3 nếu ngược lại.
a=2
b=2
if a==b:
  print(1)
elif a>b:
  print(2)
else:
  print(3)
# Out:
# 1

# %%
a=2
b=2
chuoi="Hello world"
#7.	In ra “Hello World!” nếu a bằng b và b bằng d.
d = int(input("Nhap d:"))
if a==b and b==d:
  print(chuoi.strip())
else:
  print("không thể in ra")
# Out:
# Nhap d:2
# Hello world

# %%
#8.	In ra “Hello World!” nếu a bằng b hoặc c bằng d.
a=2
b=2
d=2
c = int(input("Nhap c:"))
if a==b and c==d:
  print(chuoi.strip())
# Out:
# Nhap c:2
# Hello world

# %%
#9.	Viết lại câu lệnh if … else sau lên cùng 1 dòng.
a=2
b=2
if a==b:
  print("Yes")
else:
  print("No")
# Out:
# Yes

# %%
#10.	Nhập vào 2 số a, b. Thực hiện câu lệnh và cho biết kết quả
def nhap():
  a = int(input("Nhap a:"))
  b= int(input("Nhap b:"))
  if(a>b):
    print("A")
  elif(a==b):
    print("=")
  else:
    print("B")
nhap()
# Out:
# Nhap a:2
# Nhap b:2
# =

# %%
#11.	Tạo mảng số nguyên a với n phần tử và mảng b chỉ chứa các phần tử chẵn của a.
def bai11():
  n = int(input("Nhập số phần tử của mảng: "))
  a=[]
  for i in range(n):
    x=int(input(f"Nhập phần tử a[{i}]:"))
    a.append(x)

  b = []
  for i in a:
        if i % 2 == 0:
            b.append(i)
  print(f"Mảng a: {a}")
  print(f"Mảng b: {b}")
bai11()
# Out:
# Nhập số phần tử của mảng: 2
# Nhập phần tử a[0]:2
# Nhập phần tử a[1]:2
# Mảng a: [2, 2]
# Mảng b: [2, 2]

# %%
#12.	Viết chương trình tính tổng các số từ 0 đến 999 mà là bội của 3 hoặc 5
def bai12():
  sum=0
  for i in range(100):
    if(i%3 or i%5):
      sum+=i
  print(sum)
bai12()
# Out:
# 4635

# %%
#13 13.	Viết hàm trộn 2 mảng một chiều thành 1 mảng một chiều với mỗi phần tử của mảng mới là tổng của 2 phần tương ứng từ 2 mảng cho trước. Trong quá trình trộn 2 mảng nếu mảng nào còn phần tử thì các phần tử còn lại của mảng đó sẽ đưa vào mảng mới.
def bai13():
    a = [1, 3, 4, 6, 7]
    b = [4, 5, 3, 2, 1, 4, 5]
    maxlen = max(len(a), len(b))
    c = []

    for i in range(maxlen):
        if i < len(a):
            value_a = a[i]
        else:
            value_a = 0
        if i< len(b):
            value_b = b[i]
        else:
            value_b =0
        c.append(value_a+value_b)
    print("Mảng a:", a)
    print("Mảng b:", b)
    print("Mảng sau khi gộp là:", c)

bai13()
# Out:
# Mảng a: [1, 3, 4, 6, 7]
# Mảng b: [4, 5, 3, 2, 1, 4, 5]
# Mảng sau khi gộp là: [5, 8, 7, 8, 8, 4, 5]

# %%
#14.	Cho mảng 2 chiều a có m dòng, n cột chứa số nguyên, viết các hàm sau:
def bai14():
    a=[]#khởi tạo mãng
    m=int(input("Nhập số dòng"))
    n=int(input("Nhập số cột"))
    #điền số dòng
    for i in range(m):
        row=[]
        for j in range(n):
            x = int(input(f"Nhập phần từ a[{i}][{j}]"))
            row.append(x)
        a.append(row)
    #in ra mãng 2 chiều
    print("Mảng a: ")
    for row in a:
        print(row)
bai14()
# Out:
# Nhập số dòng2
# Nhập số cột2
# Nhập phần từ a[0][0]2
# Nhập phần từ a[0][1]2
# Nhập phần từ a[1][0]2
# Nhập phần từ a[1][1]2
# Mảng a:
# [2, 2]
# [2, 2]

# %%
import random
import numpy as np
#bài 14.aa.	Tạo mảng a chứa các số nguyên ngẫu nhiên.
import random
def bai14():
    a=[]#khởi tạo mãng
    m=int(input("Nhập số dòng"))
    n=int(input("Nhập số cột"))
    #điền số dòng
    for i in range(m):
        row=[]
        for j in range(n):
            row.append(random.randint(0,99))
        a.append(row)
    #a in ra mãng 2 chiều
    print("a, in ra mãng 2 chiều")
    print("Mảng a: ")
    for row in a:
        print(row)
    arr= np.array(a)
    #b.Xuất các phần tử thuộc dòng k
    print("b, Xuất các phần tử thuộc dòng k3")
    k = int(input("Nhập dòng bạn muốn xuất"))
    print(arr[k])

    #c.Xuất các phần tử thuộc cột k.
    print("c.Xuất các phần tử thuộc cột k.")
    h=int(input("Nhập cột bạn muốn tìm: "))
    print(arr[: , h])
    # d. Tìm dòng có tổng số lớn nhất
    print("d. Tìm dòng có tổng số lớn nhất")
    maxsum = 0
    maxindex = 0
    for idx, row in enumerate(a):   # vừa lấy chỉ số, vừa lấy dòng
        s = sum(row)                # tính tổng nhanh hơn
        if s > maxsum:
            maxsum = s
            maxindex = idx          # lưu lại chỉ số dòng

    print(f"Tổng dòng lớn nhất là {maxsum}")
    print("Dòng có tổng lớn nhất:", arr[maxindex])
     #e.	Tìm cột có tích nhỏ nhất.
    print("e.	Tìm cột có tích nhỏ nhất.")
    mintich=None
    minindex= 0
    # số cột = số phần tử trong mỗi hàng
    for j in range(len(a[0])):
        tich = 1
        for i in range(len(a)):
            tich *= a[i][j]   # nhân các phần tử trong cột j
        if mintich is None or tich < mintich:
            mintich = tich
            minindex = j

    print(f"Tích nhỏ nhất của một cột là {mintich}")
    print("Cột có tích nhỏ nhất:", [a[i][minindex] for i in range(len(a))])

    #f.	Xuất ra các phần tử thuộc dòng chẵn và cột lẻ trong a.
    print("f.	Xuất ra các phần tử thuộc dòng chẵn và cột lẻ trong a.")
    for i in range(len(a)):
        if i%2==0:
            for j in range(len(a[0])):
                if(j%2!=0):
                    print (f"[{a[i][j]}]")
    #g.	Tính trung bình cộng các phần tử chẵn thuộc dòng lẻ của a.
    print("g. Tính trung bình cộng các phần tử chẵn thuộc dòng lẻ của a.")
    tong = 0
    dem = 0
    for i in range(len(a)):
        if i % 2 != 0:  # dòng lẻ
            for j in range(len(a[0])):
                if a[i][j] % 2 == 0:  # phần tử chẵn
                    tong += a[i][j]
                    dem += 1
    if dem > 0:
        print(f"Trung bình cộng các phần tử chẵn thuộc dòng lẻ: {tong/dem}")
    else:
        print("Không có phần tử chẵn nào trong dòng lẻ.")

    #h.	Tính trung bình cộng các phần tử thuộc biên.
    print("h.	Tính trung bình cộng các phần tử thuộc biên.")
    tong =0
    dem =0
    for i in range(len(a)):
        for j in range(len(a[0])):
            if i == 0 or i == len(a)-1 or j == 0 or j == len(a[0])-1:
                tong+=a[i][j]
                dem+=1
    if dem>0:
        tb_bien=tong/dem
        print(f"Trung bình cộng các phần tử thuộc biên a: {tb_bien}")
    else:
        print("Không có phần tử thuộc biên.")
     #i.	Tính trung bình tích các phần tử không thuộc biên.
    print("i. Tính trung bình cộng các phần tử không thuộc biên.")
    tong_i = 0
    dem_i = 0
    for i in range(1, len(a)-1):
        for j in range(1, len(a[0])-1):
            tong_i += a[i][j]
            dem_i += 1
    if dem_i > 0:
        print(f"Trung bình cộng các phần tử không thuộc biên: {tong_i/dem_i}")
    else:
        print("Không có phần tử không thuộc biên.")

bai14()
# Out:
# Nhập số dòng3
# Nhập số cột3
# a, in ra mãng 2 chiều
# Mảng a:
# [83, 99, 16]
# [2, 40, 40]
# [62, 76, 54]
# b, Xuất các phần tử thuộc dòng k3
# Nhập dòng bạn muốn xuất2
# [62 76 54]
# c.Xuất các phần tử thuộc cột k.
# Nhập cột bạn muốn tìm: 2
# [16 40 54]
# d. Tìm dòng có tổng số lớn nhất
# Tổng dòng lớn nhất là 198
# Dòng có tổng lớn nhất: [83 99 16]
# e.	Tìm cột có tích nhỏ nhất.
# Tích nhỏ nhất của một cột là 10292
# Cột có tích nhỏ nhất: [83, 2, 62]
# f.	Xuất ra các phần tử thuộc dòng chẵn và cột lẻ trong a.
# [99]
# [76]
# g. Tính trung bình cộng các phần tử chẵn thuộc dòng lẻ của a.
# Trung bình cộng các phần tử chẵn thuộc dòng lẻ: 27.333333333333332
# h.	Tính trung bình cộng các phần tử thuộc biên.
# Trung bình cộng các phần tử thuộc biên a: 54.0
# i. Tính trung bình cộng các phần tử không thuộc biên.
# Trung bình cộng các phần tử không thuộc biên: 40.0

# %%
#Bài 15
#a. Xây dựng cấu trúc SINHVIEN
print("a. Xây dựng cấu trúc SINHVIEN")
class sinhvien:
    def __init__(sv, masv, tensv, namsinh, diemtb):
        sv.masv= masv #10 ký tự
        sv.tensv= tensv #20 ký tự
        sv.namsinh =namsinh #int
        sv.diemtb = diemtb #float
#b. Cho một mảng có n sinh viên
print("b. Cho một mảng có n sinh viên")
ds_dv =[sinhvien("10DH0023","Lan",2006,8.9),
        sinhvien("22DH2321","Phan An",2005,7.9),
        sinhvien("21CD3243","Lam Anh",2004,3),
        sinhvien("11DH3322","Lan",2006,8.9)
        ]

#c.	Viết hàm cho biết có bao sinh viên đủ điều kiện lên lớp, biết rằng sinh viên đủ điều kiện lên lớp khi điểm trung bình lớn hơn hoặc bằng 5.
print("c.	Viết hàm cho biết có bao sinh viên đủ điều kiện lên lớp, biết rằng sinh viên đủ điều kiện lên lớp khi điểm trung bình lớn hơn hoặc bằng 5")
def ds_du_dk(ds):
    count=0
    for sv in ds:
        if sv.diemtb>=5:
            count+=1
    return(count)
print("Số sinh viên đủ điều kiện lên lớp:", ds_du_dk(ds_dv))
#d.	Xuất các sinh viên đủ 20 tuổi.
print("d.	Xuất các sinh viên đủ 20 tuổi.")
def ds_du_20(ds):
    for sv in ds:
        if 2026 - sv.namsinh==20:
            print(f"{sv.masv} - {sv.tensv} - {sv.namsinh} - {sv.diemtb}")

ds_du_20(ds_dv)

#e.	Đếm số sinh viên học hệ đại học, biết rằng sinh viên hệ DH có mã sinh viên chứa 2 ký tự DH ở vị trí 2,3 trong chuỗi. VD: 02DH0001.
print("e.	Đếm số sinh viên học hệ đại học, biết rằng sinh viên hệ DH có mã sinh viên chứa 2 ký tự DH ở vị trí 2,3 trong chuỗi. VD: 02DH0001.")
def count_sv_dh(ds):
    count=0
    for sv in ds:
        if (sv.masv[2:4]=="DH"):
            count+=1
    return count
print("Số sinh viên hệ đại học:", count_sv_dh(ds_dv))

#f.	Cho biết trong mảng có bao nhiêu sinh viên có tên «Lan»
print("f.	Cho biết trong mảng có bao nhiêu sinh viên có tên «Lan»")
def find_sv_lan(ds):
    count =0
    for sv in ds:
        if(sv.tensv.endswith("Lan")):
            count+=1
    return count
print("Số sinh viên tên Lan:", find_sv_lan(ds_dv))

#g.	Cho biết trong mảng có bao nhiêu sinh viên có họ «Phan»
print("g.	Cho biết trong mảng có bao nhiêu sinh viên có họ «Phan»")
def count_sv_hophan(ds):
    count =0
    for sv in ds:
        if(sv.tensv.startswith("Phan")):
            count+=1
    return count
print("Số sinh viên họ Phan:", count_sv_hophan(ds_dv))
# Out:
# a. Xây dựng cấu trúc SINHVIEN
# b. Cho một mảng có n sinh viên
# c.	Viết hàm cho biết có bao sinh viên đủ điều kiện lên lớp, biết rằng sinh viên đủ điều kiện lên lớp khi điểm trung bình lớn hơn hoặc bằng 5
# Số sinh viên đủ điều kiện lên lớp: 3
# d.	Xuất các sinh viên đủ 20 tuổi.
# 10DH0023 - Lan - 2006 - 8.9
# 11DH3322 - Lan - 2006 - 8.9
# e.	Đếm số sinh viên học hệ đại học, biết rằng sinh viên hệ DH có mã sinh viên chứa 2 ký tự DH ở vị trí 2,3 trong chuỗi. VD: 02DH0001.
# Số sinh viên hệ đại học: 3
# f.	Cho biết trong mảng có bao nhiêu sinh viên có tên «Lan»
# Số sinh viên tên Lan: 2
# g.	Cho biết trong mảng có bao nhiêu sinh viên có họ «Phan»
# Số sinh viên họ Phan: 1
